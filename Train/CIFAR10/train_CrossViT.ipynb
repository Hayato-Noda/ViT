# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import os
from PIL import Image
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm
#from linformer import Linformer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install einops
# %pip install wandb
# Out:
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Installing collected packages: einops
# Successfully installed einops-0.3.0
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/67/5a/b037b50f9849212863a2fed313624d8f6f33ffa4ce89dc706e2a0e98c780/wandb-0.10.29-py2.py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 6.4MB/s
# Collecting pathtools
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/a6/99/98019716955ba243657daedd1de8f3a88ca1f5b75057c38e959db22fb87b/GitPython-3.1.14-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 26.7MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f3/92/5a33be64990ba815364a8f2dd9e6f51de60d23dfddafb4f1fc5577d4dc64/sentry_sdk-1.0.0-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 23.3MB/s
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 10.0MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/fd/01/ff260a18caaf4457eb028c96eeb405c4a230ca06c8ec9c1379f813caa52e/configparser-5.0.2-py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.0->wandb) (56.0.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/ea/e8/f414d1a4f0bbc668ed441f74f44c116d9816833a48bf81d22b697090dba8/gitdb-4.0.7-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.5MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Collecting smmap<5,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/68/ee/d540eb5e5996eb81c26ceffac6ee49041d473bc5125f2aa995cf51ec1cf1/smmap-4.0.0-py2.py3-none-any.whl
# Building wheels for collected packages: pathtools, subprocess32
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp37-none-any.whl size=8786 sha256=fe19aa9c36728e90a3b61aca7a02dad450e3362e0808831cd9ad5b935364c590
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp37-none-any.whl size=6489 sha256=c851781553ed5b8672a93a999277cfee9492cf0c57a66a7cb0b39263773256a5
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# Successfully built pathtools subprocess32
# Installing collected packages: pathtools, docker-pycreds, shortuuid, smmap, gitdb, GitPython, sentry-sdk, subprocess32, configparser, wandb
# Successfully installed GitPython-3.1.14 configparser-5.0.2 docker-pycreds-0.4.0 gitdb-4.0.7 pathtools-0.1.2 sentry-sdk-1.0.0 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 wandb-0.10.29

# %%
# %cd drive/MyDrive/Colab Notebooks/ViT
# Out:
# /content/drive/MyDrive/Colab Notebooks/ViT

# %%
from model.Cross_ViT import CrossViT
from dataloader import set_transforms
from utils.utils import seed_everything

seed_everything(42)

# %%
import torch.backends.cudnn as cudnn

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
use_cuda = torch.cuda.is_available()
cudnn.benchmark = True
print('Use CUDA:', use_cuda)
# Out:
# Use CUDA: True

# %%
config={
    "epochs": 20, 
    "batch_size": 64,
    "lr" : 3e-5,
    "gamma" : 0.7,
    "image_size" : 32,
    "patch_size" : 16,
    "num_classes" : 10,
    "dim" : 128,
    "depth" : 3,
    "heads" : 8,
    "mlp_dim" : 1024,
    "channels" : 3,
    "dropout" : 0.,
    "emb_dropout": 0.
    }

# Training settings
import wandb
wandb.init(config=config, project="Cifar10_ViT", entity='NoguNogu',name='CrossViT')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.29<br/>
#                 Syncing run <strong style="color:#cdcd00">CrossViT</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nogunogu/Cifar10_ViT" target="_blank">https://wandb.ai/nogunogu/Cifar10_ViT</a><br/>
#                 Run page: <a href="https://wandb.ai/nogunogu/Cifar10_ViT/runs/1kwemlz0" target="_blank">https://wandb.ai/nogunogu/Cifar10_ViT/runs/1kwemlz0</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/Colab Notebooks/ViT/wandb/run-20210506_120513-1kwemlz0</code><br/><br/>
# <h1>Run(1kwemlz0)</h1><iframe src="https://wandb.ai/nogunogu/Cifar10_ViT/runs/1kwemlz0" style="border:none;width:100%;height:400px"></iframe>

# %%
trainloader, testloader = set_transforms(
    config['image_size'],
    config['batch_size'],
    name='Cifar10')._set_transforms()

# %%
model = CrossViT(
    image_size = config['image_size'],
    num_classes = config['num_classes'],
    sm_patch_size = 8,
    sm_dim = config['dim'],
    lg_dim = config['dim'],
    depth = config['depth'],
    dropout = config['dropout'],
    emb_dropout = config['emb_dropout']
    ).to(device)

# %%
from torchsummary import summary
summary(model, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          Rearrange-1              [-1, 16, 192]               0
#             Linear-2              [-1, 16, 128]          24,704
#            Dropout-3              [-1, 17, 128]               0
#   Patch_Linear_emb-4              [-1, 17, 128]               0
#          Rearrange-5               [-1, 4, 768]               0
#             Linear-6               [-1, 4, 128]          98,432
#            Dropout-7               [-1, 5, 128]               0
#   Patch_Linear_emb-8               [-1, 5, 128]               0
#          LayerNorm-9              [-1, 17, 128]             256
#            Linear-10              [-1, 17, 512]          65,536
#            Linear-11             [-1, 17, 1024]         131,072
#           Softmax-12            [-1, 8, 17, 17]               0
#            Linear-13              [-1, 17, 128]          65,664
#           Dropout-14              [-1, 17, 128]               0
#         Attention-15              [-1, 17, 128]               0
#           PreNorm-16              [-1, 17, 128]               0
#         LayerNorm-17              [-1, 17, 128]             256
#            Linear-18             [-1, 17, 2048]         264,192
#              GELU-19             [-1, 17, 2048]               0
#           Dropout-20             [-1, 17, 2048]               0
#            Linear-21              [-1, 17, 128]         262,272
#           Dropout-22              [-1, 17, 128]               0
#       FeedForward-23              [-1, 17, 128]               0
#           PreNorm-24              [-1, 17, 128]               0
#         LayerNorm-25              [-1, 17, 128]             256
#       Transformer-26              [-1, 17, 128]               0
#         LayerNorm-27               [-1, 5, 128]             256
#            Linear-28               [-1, 5, 512]          65,536
#            Linear-29              [-1, 5, 1024]         131,072
#           Softmax-30              [-1, 8, 5, 5]               0
#            Linear-31               [-1, 5, 128]          65,664
#           Dropout-32               [-1, 5, 128]               0
#         Attention-33               [-1, 5, 128]               0
#           PreNorm-34               [-1, 5, 128]               0
#         LayerNorm-35               [-1, 5, 128]             256
#            Linear-36              [-1, 5, 2048]         264,192
#              GELU-37              [-1, 5, 2048]               0
#           Dropout-38              [-1, 5, 2048]               0
#            Linear-39               [-1, 5, 128]         262,272
#           Dropout-40               [-1, 5, 128]               0
#       FeedForward-41               [-1, 5, 128]               0
#           PreNorm-42               [-1, 5, 128]               0
#         LayerNorm-43               [-1, 5, 128]             256
#            Linear-44               [-1, 5, 512]          65,536
#            Linear-45              [-1, 5, 1024]         131,072
#           Softmax-46              [-1, 8, 5, 5]               0
#            Linear-47               [-1, 5, 128]          65,664
#           Dropout-48               [-1, 5, 128]               0
#         Attention-49               [-1, 5, 128]               0
#           PreNorm-50               [-1, 5, 128]               0
#         LayerNorm-51               [-1, 5, 128]             256
#            Linear-52              [-1, 5, 2048]         264,192
#              GELU-53              [-1, 5, 2048]               0
#           Dropout-54              [-1, 5, 2048]               0
#            Linear-55               [-1, 5, 128]         262,272
#           Dropout-56               [-1, 5, 128]               0
#       FeedForward-57               [-1, 5, 128]               0
#           PreNorm-58               [-1, 5, 128]               0
#         LayerNorm-59               [-1, 5, 128]             256
#            Linear-60               [-1, 5, 512]          65,536
#            Linear-61              [-1, 5, 1024]         131,072
#           Softmax-62              [-1, 8, 5, 5]               0
#            Linear-63               [-1, 5, 128]          65,664
#           Dropout-64               [-1, 5, 128]               0
#         Attention-65               [-1, 5, 128]               0
#           PreNorm-66               [-1, 5, 128]               0
#         LayerNorm-67               [-1, 5, 128]             256
#            Linear-68              [-1, 5, 2048]         264,192
#              GELU-69              [-1, 5, 2048]               0
#           Dropout-70              [-1, 5, 2048]               0
#            Linear-71               [-1, 5, 128]         262,272
#           Dropout-72               [-1, 5, 128]               0
#       FeedForward-73               [-1, 5, 128]               0
#           PreNorm-74               [-1, 5, 128]               0
#         LayerNorm-75               [-1, 5, 128]             256
#            Linear-76               [-1, 5, 512]          65,536
#            Linear-77              [-1, 5, 1024]         131,072
#           Softmax-78              [-1, 8, 5, 5]               0
#            Linear-79               [-1, 5, 128]          65,664
#           Dropout-80               [-1, 5, 128]               0
#         Attention-81               [-1, 5, 128]               0
#           PreNorm-82               [-1, 5, 128]               0
#         LayerNorm-83               [-1, 5, 128]             256
#            Linear-84              [-1, 5, 2048]         264,192
#              GELU-85              [-1, 5, 2048]               0
#           Dropout-86              [-1, 5, 2048]               0
#            Linear-87               [-1, 5, 128]         262,272
#           Dropout-88               [-1, 5, 128]               0
#       FeedForward-89               [-1, 5, 128]               0
#           PreNorm-90               [-1, 5, 128]               0
#         LayerNorm-91               [-1, 5, 128]             256
#       Transformer-92               [-1, 5, 128]               0
#          Identity-93               [-1, 1, 128]               0
#         LayerNorm-94               [-1, 1, 128]             256
#            Linear-95               [-1, 1, 512]          65,536
#            Linear-96              [-1, 5, 1024]         131,072
#           Softmax-97              [-1, 8, 1, 5]               0
#            Linear-98               [-1, 1, 128]          65,664
#           Dropout-99               [-1, 1, 128]               0
#        Attention-100               [-1, 1, 128]               0
#          PreNorm-101               [-1, 1, 128]               0
#         Identity-102               [-1, 1, 128]               0
#     ProjectInOut-103               [-1, 1, 128]               0
#         Identity-104               [-1, 1, 128]               0
#        LayerNorm-105               [-1, 1, 128]             256
#           Linear-106               [-1, 1, 512]          65,536
#           Linear-107             [-1, 17, 1024]         131,072
#          Softmax-108             [-1, 8, 1, 17]               0
#           Linear-109               [-1, 1, 128]          65,664
#          Dropout-110               [-1, 1, 128]               0
#        Attention-111               [-1, 1, 128]               0
#          PreNorm-112               [-1, 1, 128]               0
#         Identity-113               [-1, 1, 128]               0
#     ProjectInOut-114               [-1, 1, 128]               0
#         Identity-115               [-1, 1, 128]               0
#        LayerNorm-116               [-1, 1, 128]             256
#           Linear-117               [-1, 1, 512]          65,536
#           Linear-118              [-1, 5, 1024]         131,072
#          Softmax-119              [-1, 8, 1, 5]               0
#           Linear-120               [-1, 1, 128]          65,664
#          Dropout-121               [-1, 1, 128]               0
#        Attention-122               [-1, 1, 128]               0
#          PreNorm-123               [-1, 1, 128]               0
#         Identity-124               [-1, 1, 128]               0
#     ProjectInOut-125               [-1, 1, 128]               0
#         Identity-126               [-1, 1, 128]               0
#        LayerNorm-127               [-1, 1, 128]             256
#           Linear-128               [-1, 1, 512]          65,536
#           Linear-129             [-1, 17, 1024]         131,072
#          Softmax-130             [-1, 8, 1, 17]               0
#           Linear-131               [-1, 1, 128]          65,664
#          Dropout-132               [-1, 1, 128]               0
#        Attention-133               [-1, 1, 128]               0
#          PreNorm-134               [-1, 1, 128]               0
#         Identity-135               [-1, 1, 128]               0
#     ProjectInOut-136               [-1, 1, 128]               0
# CrossTransformer-137  [[-1, 17, 128], [-1, 5, 128]]               0
#        LayerNorm-138              [-1, 17, 128]             256
#           Linear-139              [-1, 17, 512]          65,536
#           Linear-140             [-1, 17, 1024]         131,072
#          Softmax-141            [-1, 8, 17, 17]               0
#           Linear-142              [-1, 17, 128]          65,664
#          Dropout-143              [-1, 17, 128]               0
#        Attention-144              [-1, 17, 128]               0
#          PreNorm-145              [-1, 17, 128]               0
#        LayerNorm-146              [-1, 17, 128]             256
#           Linear-147             [-1, 17, 2048]         264,192
#             GELU-148             [-1, 17, 2048]               0
#          Dropout-149             [-1, 17, 2048]               0
#           Linear-150              [-1, 17, 128]         262,272
#          Dropout-151              [-1, 17, 128]               0
#      FeedForward-152              [-1, 17, 128]               0
#          PreNorm-153              [-1, 17, 128]               0
#        LayerNorm-154              [-1, 17, 128]             256
#      Transformer-155              [-1, 17, 128]               0
#        LayerNorm-156               [-1, 5, 128]             256
#           Linear-157               [-1, 5, 512]          65,536
#           Linear-158              [-1, 5, 1024]         131,072
#          Softmax-159              [-1, 8, 5, 5]               0
#           Linear-160               [-1, 5, 128]          65,664
#          Dropout-161               [-1, 5, 128]               0
#        Attention-162               [-1, 5, 128]               0
#          PreNorm-163               [-1, 5, 128]               0
#        LayerNorm-164               [-1, 5, 128]             256
#           Linear-165              [-1, 5, 2048]         264,192
#             GELU-166              [-1, 5, 2048]               0
#          Dropout-167              [-1, 5, 2048]               0
#           Linear-168               [-1, 5, 128]         262,272
#          Dropout-169               [-1, 5, 128]               0
#      FeedForward-170               [-1, 5, 128]               0
#          PreNorm-171               [-1, 5, 128]               0
#        LayerNorm-172               [-1, 5, 128]             256
#           Linear-173               [-1, 5, 512]          65,536
#           Linear-174              [-1, 5, 1024]         131,072
#          Softmax-175              [-1, 8, 5, 5]               0
#           Linear-176               [-1, 5, 128]          65,664
#          Dropout-177               [-1, 5, 128]               0
#        Attention-178               [-1, 5, 128]               0
#          PreNorm-179               [-1, 5, 128]               0
#        LayerNorm-180               [-1, 5, 128]             256
#           Linear-181              [-1, 5, 2048]         264,192
#             GELU-182              [-1, 5, 2048]               0
#          Dropout-183              [-1, 5, 2048]               0
#           Linear-184               [-1, 5, 128]         262,272
#          Dropout-185               [-1, 5, 128]               0
#      FeedForward-186               [-1, 5, 128]               0
#          PreNorm-187               [-1, 5, 128]               0
#        LayerNorm-188               [-1, 5, 128]             256
#           Linear-189               [-1, 5, 512]          65,536
#           Linear-190              [-1, 5, 1024]         131,072
#          Softmax-191              [-1, 8, 5, 5]               0
#           Linear-192               [-1, 5, 128]          65,664
#          Dropout-193               [-1, 5, 128]               0
#        Attention-194               [-1, 5, 128]               0
#          PreNorm-195               [-1, 5, 128]               0
#        LayerNorm-196               [-1, 5, 128]             256
#           Linear-197              [-1, 5, 2048]         264,192
#             GELU-198              [-1, 5, 2048]               0
#          Dropout-199              [-1, 5, 2048]               0
#           Linear-200               [-1, 5, 128]         262,272
#          Dropout-201               [-1, 5, 128]               0
#      FeedForward-202               [-1, 5, 128]               0
#          PreNorm-203               [-1, 5, 128]               0
#        LayerNorm-204               [-1, 5, 128]             256
#           Linear-205               [-1, 5, 512]          65,536
#           Linear-206              [-1, 5, 1024]         131,072
#          Softmax-207              [-1, 8, 5, 5]               0
#           Linear-208               [-1, 5, 128]          65,664
#          Dropout-209               [-1, 5, 128]               0
#        Attention-210               [-1, 5, 128]               0
#          PreNorm-211               [-1, 5, 128]               0
#        LayerNorm-212               [-1, 5, 128]             256
#           Linear-213              [-1, 5, 2048]         264,192
#             GELU-214              [-1, 5, 2048]               0
#          Dropout-215              [-1, 5, 2048]               0
#           Linear-216               [-1, 5, 128]         262,272
#          Dropout-217               [-1, 5, 128]               0
#      FeedForward-218               [-1, 5, 128]               0
#          PreNorm-219               [-1, 5, 128]               0
#        LayerNorm-220               [-1, 5, 128]             256
#      Transformer-221               [-1, 5, 128]               0
#         Identity-222               [-1, 1, 128]               0
#        LayerNorm-223               [-1, 1, 128]             256
#           Linear-224               [-1, 1, 512]          65,536
#           Linear-225              [-1, 5, 1024]         131,072
#          Softmax-226              [-1, 8, 1, 5]               0
#           Linear-227               [-1, 1, 128]          65,664
#          Dropout-228               [-1, 1, 128]               0
#        Attention-229               [-1, 1, 128]               0
#          PreNorm-230               [-1, 1, 128]               0
#         Identity-231               [-1, 1, 128]               0
#     ProjectInOut-232               [-1, 1, 128]               0
#         Identity-233               [-1, 1, 128]               0
#        LayerNorm-234               [-1, 1, 128]             256
#           Linear-235               [-1, 1, 512]          65,536
#           Linear-236             [-1, 17, 1024]         131,072
#          Softmax-237             [-1, 8, 1, 17]               0
#           Linear-238               [-1, 1, 128]          65,664
#          Dropout-239               [-1, 1, 128]               0
#        Attention-240               [-1, 1, 128]               0
#          PreNorm-241               [-1, 1, 128]               0
#         Identity-242               [-1, 1, 128]               0
#     ProjectInOut-243               [-1, 1, 128]               0
#         Identity-244               [-1, 1, 128]               0
#        LayerNorm-245               [-1, 1, 128]             256
#           Linear-246               [-1, 1, 512]          65,536
#           Linear-247              [-1, 5, 1024]         131,072
#          Softmax-248              [-1, 8, 1, 5]               0
#           Linear-249               [-1, 1, 128]          65,664
#          Dropout-250               [-1, 1, 128]               0
#        Attention-251               [-1, 1, 128]               0
#          PreNorm-252               [-1, 1, 128]               0
#         Identity-253               [-1, 1, 128]               0
#     ProjectInOut-254               [-1, 1, 128]               0
#         Identity-255               [-1, 1, 128]               0
#        LayerNorm-256               [-1, 1, 128]             256
#           Linear-257               [-1, 1, 512]          65,536
#           Linear-258             [-1, 17, 1024]         131,072
#          Softmax-259             [-1, 8, 1, 17]               0
#           Linear-260               [-1, 1, 128]          65,664
#          Dropout-261               [-1, 1, 128]               0
#        Attention-262               [-1, 1, 128]               0
#          PreNorm-263               [-1, 1, 128]               0
#         Identity-264               [-1, 1, 128]               0
#     ProjectInOut-265               [-1, 1, 128]               0
# CrossTransformer-266  [[-1, 17, 128], [-1, 5, 128]]               0
#        LayerNorm-267              [-1, 17, 128]             256
#           Linear-268              [-1, 17, 512]          65,536
#           Linear-269             [-1, 17, 1024]         131,072
#          Softmax-270            [-1, 8, 17, 17]               0
#           Linear-271              [-1, 17, 128]          65,664
#          Dropout-272              [-1, 17, 128]               0
#        Attention-273              [-1, 17, 128]               0
#          PreNorm-274              [-1, 17, 128]               0
#        LayerNorm-275              [-1, 17, 128]             256
#           Linear-276             [-1, 17, 2048]         264,192
#             GELU-277             [-1, 17, 2048]               0
#          Dropout-278             [-1, 17, 2048]               0
#           Linear-279              [-1, 17, 128]         262,272
#          Dropout-280              [-1, 17, 128]               0
#      FeedForward-281              [-1, 17, 128]               0
#          PreNorm-282              [-1, 17, 128]               0
#        LayerNorm-283              [-1, 17, 128]             256
#      Transformer-284              [-1, 17, 128]               0
#        LayerNorm-285               [-1, 5, 128]             256
#           Linear-286               [-1, 5, 512]          65,536
#           Linear-287              [-1, 5, 1024]         131,072
#          Softmax-288              [-1, 8, 5, 5]               0
#           Linear-289               [-1, 5, 128]          65,664
#          Dropout-290               [-1, 5, 128]               0
#        Attention-291               [-1, 5, 128]               0
#          PreNorm-292               [-1, 5, 128]               0
#        LayerNorm-293               [-1, 5, 128]             256
#           Linear-294              [-1, 5, 2048]         264,192
#             GELU-295              [-1, 5, 2048]               0
#          Dropout-296              [-1, 5, 2048]               0
#           Linear-297               [-1, 5, 128]         262,272
#          Dropout-298               [-1, 5, 128]               0
#      FeedForward-299               [-1, 5, 128]               0
#          PreNorm-300               [-1, 5, 128]               0
#        LayerNorm-301               [-1, 5, 128]             256
#           Linear-302               [-1, 5, 512]          65,536
#           Linear-303              [-1, 5, 1024]         131,072
#          Softmax-304              [-1, 8, 5, 5]               0
#           Linear-305               [-1, 5, 128]          65,664
#          Dropout-306               [-1, 5, 128]               0
#        Attention-307               [-1, 5, 128]               0
#          PreNorm-308               [-1, 5, 128]               0
#        LayerNorm-309               [-1, 5, 128]             256
#           Linear-310              [-1, 5, 2048]         264,192
#             GELU-311              [-1, 5, 2048]               0
#          Dropout-312              [-1, 5, 2048]               0
#           Linear-313               [-1, 5, 128]         262,272
#          Dropout-314               [-1, 5, 128]               0
#      FeedForward-315               [-1, 5, 128]               0
#          PreNorm-316               [-1, 5, 128]               0
#        LayerNorm-317               [-1, 5, 128]             256
#           Linear-318               [-1, 5, 512]          65,536
#           Linear-319              [-1, 5, 1024]         131,072
#          Softmax-320              [-1, 8, 5, 5]               0
#           Linear-321               [-1, 5, 128]          65,664
#          Dropout-322               [-1, 5, 128]               0
#        Attention-323               [-1, 5, 128]               0
#          PreNorm-324               [-1, 5, 128]               0
#        LayerNorm-325               [-1, 5, 128]             256
#           Linear-326              [-1, 5, 2048]         264,192
#             GELU-327              [-1, 5, 2048]               0
#          Dropout-328              [-1, 5, 2048]               0
#           Linear-329               [-1, 5, 128]         262,272
#          Dropout-330               [-1, 5, 128]               0
#      FeedForward-331               [-1, 5, 128]               0
#          PreNorm-332               [-1, 5, 128]               0
#        LayerNorm-333               [-1, 5, 128]             256
#           Linear-334               [-1, 5, 512]          65,536
#           Linear-335              [-1, 5, 1024]         131,072
#          Softmax-336              [-1, 8, 5, 5]               0
#           Linear-337               [-1, 5, 128]          65,664
#          Dropout-338               [-1, 5, 128]               0
#        Attention-339               [-1, 5, 128]               0
#          PreNorm-340               [-1, 5, 128]               0
#        LayerNorm-341               [-1, 5, 128]             256
#           Linear-342              [-1, 5, 2048]         264,192
#             GELU-343              [-1, 5, 2048]               0
#          Dropout-344              [-1, 5, 2048]               0
#           Linear-345               [-1, 5, 128]         262,272
#          Dropout-346               [-1, 5, 128]               0
#      FeedForward-347               [-1, 5, 128]               0
#          PreNorm-348               [-1, 5, 128]               0
#        LayerNorm-349               [-1, 5, 128]             256
#      Transformer-350               [-1, 5, 128]               0
#         Identity-351               [-1, 1, 128]               0
#        LayerNorm-352               [-1, 1, 128]             256
#           Linear-353               [-1, 1, 512]          65,536
#           Linear-354              [-1, 5, 1024]         131,072
#          Softmax-355              [-1, 8, 1, 5]               0
#           Linear-356               [-1, 1, 128]          65,664
#          Dropout-357               [-1, 1, 128]               0
#        Attention-358               [-1, 1, 128]               0
#          PreNorm-359               [-1, 1, 128]               0
#         Identity-360               [-1, 1, 128]               0
#     ProjectInOut-361               [-1, 1, 128]               0
#         Identity-362               [-1, 1, 128]               0
#        LayerNorm-363               [-1, 1, 128]             256
#           Linear-364               [-1, 1, 512]          65,536
#           Linear-365             [-1, 17, 1024]         131,072
#          Softmax-366             [-1, 8, 1, 17]               0
#           Linear-367               [-1, 1, 128]          65,664
#          Dropout-368               [-1, 1, 128]               0
#        Attention-369               [-1, 1, 128]               0
#          PreNorm-370               [-1, 1, 128]               0
#         Identity-371               [-1, 1, 128]               0
#     ProjectInOut-372               [-1, 1, 128]               0
#         Identity-373               [-1, 1, 128]               0
#        LayerNorm-374               [-1, 1, 128]             256
#           Linear-375               [-1, 1, 512]          65,536
#           Linear-376              [-1, 5, 1024]         131,072
#          Softmax-377              [-1, 8, 1, 5]               0
#           Linear-378               [-1, 1, 128]          65,664
#          Dropout-379               [-1, 1, 128]               0
#        Attention-380               [-1, 1, 128]               0
#          PreNorm-381               [-1, 1, 128]               0
#         Identity-382               [-1, 1, 128]               0
#     ProjectInOut-383               [-1, 1, 128]               0
#         Identity-384               [-1, 1, 128]               0
#        LayerNorm-385               [-1, 1, 128]             256
#           Linear-386               [-1, 1, 512]          65,536
#           Linear-387             [-1, 17, 1024]         131,072
#          Softmax-388             [-1, 8, 1, 17]               0
#           Linear-389               [-1, 1, 128]          65,664
#          Dropout-390               [-1, 1, 128]               0
#        Attention-391               [-1, 1, 128]               0
#          PreNorm-392               [-1, 1, 128]               0
#         Identity-393               [-1, 1, 128]               0
#     ProjectInOut-394               [-1, 1, 128]               0
# CrossTransformer-395  [[-1, 17, 128], [-1, 5, 128]]               0
# MultiScaleEncoder-396  [[-1, 17, 128], [-1, 5, 128]]               0
#        LayerNorm-397                  [-1, 128]             256
#           Linear-398                   [-1, 10]           1,290
#        LayerNorm-399                  [-1, 128]             256
#           Linear-400                   [-1, 10]           1,290
# ================================================================
# Total params: 15,116,820
# Trainable params: 15,116,820
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 33.42
# Params size (MB): 57.67
# Estimated Total Size (MB): 91.10
# ----------------------------------------------------------------

# %%
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=config['lr'])
# scheduler
scheduler = StepLR(optimizer, step_size=1, gamma=config['gamma'])

# %%
# 3. Log gradients and model parameters
wandb.watch(model, log_freq=100)
for epoch in range(config['epochs']):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(trainloader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(trainloader)
        epoch_loss += loss / len(trainloader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in testloader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(testloader)
            epoch_val_loss += val_loss / len(testloader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )

    # 4. Log metrics to visualize performance
    wandb.log({
        "Epoch": epoch+1,
        "loss": epoch_loss,
        "acc": epoch_accuracy,
        "val_loss" : epoch_val_loss,
        "val_acc": epoch_val_accuracy
        })
# Out:
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 1 - loss : 2.0774 - acc: 0.2233 - val_loss : 1.9658 - val_acc: 0.2726
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 2 - loss : 1.9292 - acc: 0.2875 - val_loss : 1.8487 - val_acc: 0.3198
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 3 - loss : 1.8385 - acc: 0.3218 - val_loss : 1.8118 - val_acc: 0.3393
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 4 - loss : 1.7855 - acc: 0.3482 - val_loss : 1.7523 - val_acc: 0.3691
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 5 - loss : 1.7388 - acc: 0.3637 - val_loss : 1.7191 - val_acc: 0.3777
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 6 - loss : 1.7083 - acc: 0.3807 - val_loss : 1.7083 - val_acc: 0.3849
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 7 - loss : 1.6789 - acc: 0.3898 - val_loss : 1.6679 - val_acc: 0.3959
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 8 - loss : 1.6551 - acc: 0.4005 - val_loss : 1.6294 - val_acc: 0.4083
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 9 - loss : 1.6339 - acc: 0.4066 - val_loss : 1.6351 - val_acc: 0.4068
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 10 - loss : 1.6141 - acc: 0.4169 - val_loss : 1.6141 - val_acc: 0.4169
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 11 - loss : 1.5903 - acc: 0.4271 - val_loss : 1.5695 - val_acc: 0.4423
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 12 - loss : 1.5829 - acc: 0.4266 - val_loss : 1.5882 - val_acc: 0.4306
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 13 - loss : 1.5697 - acc: 0.4360 - val_loss : 1.5736 - val_acc: 0.4318
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 14 - loss : 1.5547 - acc: 0.4388 - val_loss : 1.5531 - val_acc: 0.4419
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 15 - loss : 1.5371 - acc: 0.4482 - val_loss : 1.5555 - val_acc: 0.4387
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 16 - loss : 1.5236 - acc: 0.4502 - val_loss : 1.5337 - val_acc: 0.4520
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 17 - loss : 1.5150 - acc: 0.4569 - val_loss : 1.5253 - val_acc: 0.4516
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 18 - loss : 1.5065 - acc: 0.4583 - val_loss : 1.5315 - val_acc: 0.4528
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 19 - loss : 1.4885 - acc: 0.4619 - val_loss : 1.4958 - val_acc: 0.4696
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# Epoch : 20 - loss : 1.4831 - acc: 0.4671 - val_loss : 1.5100 - val_acc: 0.4556

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu May  6 12:05:32 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    30W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
